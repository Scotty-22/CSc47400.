# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

b1 = data['B1'].ravel()[sampleInds]
b6 = data['B6'].ravel()[sampleInds]

m1, c1 = np.polyfit(b1, b6, 1)
r1 = pearsonr(b1, b6)[0]

plt.figure(figsize=(5,4))
plt.scatter(b1, b6, s=8, alpha=0.3)
xline = np.array([b1.min(), b1.max()])
plt.plot(xline, m1 * xline + c1, 'r', label=f'r = {r1:.2f}')
plt.title('Band 1 vs Band 6')
plt.xlabel('Band 1')
plt.ylabel('Band 6')
plt.legend()
plt.show()
