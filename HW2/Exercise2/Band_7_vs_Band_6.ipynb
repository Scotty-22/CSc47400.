# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

b7 = data['B7'].ravel()[sampleInds]
b6 = data['B6'].ravel()[sampleInds]

m2, c2 = np.polyfit(b7, b6, 1)
r2 = pearsonr(b7, b6)[0]

plt.figure(figsize=(5,4))
plt.scatter(b7, b6, s=8, alpha=0.3)
xline = np.array([b7.min(), b7.max()])
plt.plot(xline, m2 * xline + c2, 'r', label=f'r = {r2:.2f}')
plt.title('Band 7 vs Band 6')
plt.xlabel('Band 7')
plt.ylabel('Band 6')
plt.legend()
plt.show()
